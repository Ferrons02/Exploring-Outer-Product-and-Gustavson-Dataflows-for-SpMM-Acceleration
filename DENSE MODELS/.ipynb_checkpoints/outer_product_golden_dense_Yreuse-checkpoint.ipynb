# %% [markdown]
# Let's first initialize the matrices and some variables

# %%
from generate_sparse_matrix import generate_sparse_matrix
import math
import matplotlib.pyplot as plt
import numpy as np

# Matrix generation
In_data_size = 8  # has to be a multiple of 8 such that the memory locations are not segmented
Out_data_size = 24  # has to be a multiple of 8 such that the memory locations are not segmented

X_rows, X_columns, X_sparsity = 4, 4, 0.1  # X_columns = Y_rows
Y_rows, Y_columns, Y_sparsity = 4, 4, 0.1

# Sizes of X and Y tiles
X_elem_size = 2
Y_elem_size = 2

X = generate_sparse_matrix(X_rows, X_columns, X_sparsity, In_data_size)
Y = generate_sparse_matrix(Y_rows, Y_columns, Y_sparsity, In_data_size)
Z = [['0' * Out_data_size for _ in range(Y_columns)] for _ in range(X_rows)]

# initialization of vectors of data usage
X_offset_addr = []
Y_offset_addr = []
Z_offset_addr = []

# initialization of starting addresses
Z_start_addr = 0

# Number of X_column_blocks for A and B
X_column_blocks = math.ceil(X_columns / X_elem_size)
Y_row_blocks = math.ceil(Y_rows / Y_elem_size)

# %% [markdown]
# Now we simulate the calculation using this 3 nested loops; one along the rows of X, one along che column blocks of Y and one along both the column blocks of X and row blocks of Y; inside this three nested loops we have two other nested loops that just compute the result; once this has been done, the list of access patterns is updated

# %%
for k in range(X_columns):
    for Y_row_block in range(Y_row_blocks):

        start_Y = Y_row_block * Y_elem_size
        end_Y = min(start_Y + Y_elem_size, Y_columns)

        # Load tile of Y
        Y_tile = Y[k][start_Y:end_Y]

        for X_column_block in range(X_column_blocks):

            start_X = X_column_block * X_elem_size
            end_X = min(start_X + X_elem_size, X_rows)

            # Load tile of X
            X_tile = [X[j][k] for j in range(start_X, end_X)]

            # Initialize output buffer
            out_buffer = [Z[j][start_Y:end_Y] for j in range(start_X, end_X)]

            # region COMPUTING THE RESULT FOR THE SPECIFIC CYCLE

            # Multiply-accumulate
            for x_idx, x_bin in enumerate(X_tile):
                x_val = int(x_bin, 2)
                for y_idx in range(end_Y - start_Y):
                    y_val = int(Y_tile[y_idx], 2)
                    acc = int(out_buffer[x_idx][y_idx], 2)
                    acc += x_val * y_val
                    acc &= (1 << Out_data_size) - 1
                    out_buffer[x_idx][y_idx] = format(acc, f'0{Out_data_size}b')

            # endregion

            # Store in Z
            for i in range(end_X - start_X):
                Z[start_X + i][start_Y:end_Y] = out_buffer[i]

            # region APPENDING DATA ITEMS INFORMATION

            # Offset addresses for the current cycle
            X_start_addr = (X_column_block * X_elem_size * X_columns + k) * (In_data_size / 8)
            Y_start_addr = (Y_row_block * Y_elem_size * Y_rows + k) * (In_data_size / 8)
            Z_start_addr = (X_column_block * X_elem_size * Y_columns + Y_row_block * Y_elem_size) * (
                        Out_data_size / 8)

            # Load the addresses of the accessed elements of each matrix for this cycle
            cycle_X = [X_start_addr + i * (In_data_size / 8) * X_columns for i in range(X_elem_size)]
            cycle_Y = [Y_start_addr + i * (In_data_size / 8) * Y_rows for i in range(Y_elem_size)]
            cycle_Z = []
            for step in range(X_elem_size):
                base_offset = step * (Y_columns * (Out_data_size / 8))
                for offset in range(Y_elem_size):
                    cycle_Z.append(Z_start_addr + base_offset + offset * (Out_data_size / 8))

            # Add the cycle address information to the list
            X_offset_addr.append(cycle_X)
            Y_offset_addr.append(cycle_Y)
            Z_offset_addr.append(cycle_Z)

            # endregion

# At the end as final step I duplicate the first and last elements of the list to account for the first load cycle and the last store cycle where no computation is done

X_offset_addr = [X_offset_addr[0]] + X_offset_addr + [X_offset_addr[-1]]
Y_offset_addr = [Y_offset_addr[0]] + Y_offset_addr + [Y_offset_addr[-1]]
Z_offset_addr = [Z_offset_addr[0]] + Z_offset_addr + [Z_offset_addr[-1]]

# %% [markdown]
# Now that the calculation is complete and we've gathered enough data we put everything together by calculating some figures of merit

# %%
# LATENCY CALCULATION

latency = X_columns * Y_row_blocks * X_column_blocks + 2

# BANDWIDTH CALCULATION

Input_avg_bandwidth = X_elem_size * (In_data_size / 8) + X_elem_size * Y_elem_size * (Out_data_size / 8)
Output_avg_bandwidth = X_elem_size * Y_elem_size * (Out_data_size / 8)

Input_peak_bandwidth = Y_elem_size * (In_data_size / 8) + X_elem_size * Y_elem_size * (
            Out_data_size / 8) + X_elem_size * (In_data_size / 8)
Output_peak_bandwidth = X_elem_size * Y_elem_size * (Out_data_size / 8)

Combined_avg_bandwidth = Input_avg_bandwidth + Output_avg_bandwidth
Combined_peak_bandwidth = Input_peak_bandwidth + Output_peak_bandwidth

# REUSE DISTANCE CALCULATION

X_reuse_distance = Y_row_blocks
Y_reuse_distance = 0
Z_reuse_distance = X_column_blocks * Y_row_blocks

# %% [markdown]
# Now we print these figure of merit and plot the results

# %%
# region PRINTING AND DATA ITEMS PLOT

print("Reuse policy: Y\n")
print("Latency: " + f"{int(latency)}" + " cycles")
print(f"Average Input bandwidth: " + f"{int(Input_avg_bandwidth)}" + " Bytes/ cycle")
print(f"Peak Input bandwidth: " + f"{int(Input_peak_bandwidth)}" + " Bytes/ cycle")
print(f"Average Output bandwidth: " + f"{int(Output_avg_bandwidth)}" + " Bytes/ cycle")
print(f"Peak Output bandwidth: " + f"{int(Output_peak_bandwidth)}" + " Bytes/ cycle")
print(f"Average Combined bandwidth: " + f"{int(Combined_avg_bandwidth)}" + " Bytes/ cycle")
print(f"Peak Combined bandwidth: " + f"{int(Combined_peak_bandwidth)}" + " Bytes/ cycle")
print(f"X Reuse Distance (cycles): {X_reuse_distance}")
print(f"Y Reuse Distance (cycles): {Y_reuse_distance}")
print(f"Z Reuse Distance (cycles): {Z_reuse_distance}\n")

indices = [(X_offset_addr, 'Offset address', 'X elements usage', 'blue', 'o', X_reuse_distance,
            X_elem_size * (In_data_size / 8)),
           (Y_offset_addr, 'Offset address', 'Y elements usage', 'green', 'o', X_reuse_distance,
            (Y_rows * (In_data_size / 8))),
           (Z_offset_addr, 'Offset address', 'Z elements usage', 'red', 'o', Z_reuse_distance,
            X_elem_size * (Out_data_size / 8))]

for vals, y_label, label, color, marker, x_spacing, y_spacing in indices:
    plt.figure(figsize=(6, 4))

    # Calculate x values based on the number of cycles (use the range of indices for x-axis)
    x = np.arange(1, len(vals) + 2)  # x will range from 1 to the number of cycles in vals

    for i, cycle in enumerate(vals):
        plt.plot([i + 1] * len(cycle), cycle, color=color, marker=marker, linestyle='None')

    plt.xlabel('Cycle')
    plt.ylabel(y_label)
    plt.title(f'{label}')

    # Set tick positions with customized offset and spacing for x-axis
    plt.xticks(np.arange(min(x) + 1, max(x) + 1, x_spacing))

    # Set tick positions for y-axis with custom offset and spacing
    flattened_vals = [item for sublist in vals for item in sublist]
    plt.yticks(np.arange(int(min(flattened_vals)), int(max(flattened_vals)) + 1, y_spacing))

    plt.grid(True)
    plt.show()

# endregion
# Out:
# Reuse policy: Y
#
# Latency: 18 cycles
# Average Input bandwidth: 14 Bytes/ cycle
# Peak Input bandwidth: 16 Bytes/ cycle
# Average Output bandwidth: 12 Bytes/ cycle
# Peak Output bandwidth: 12 Bytes/ cycle
# Average Combined bandwidth: 26 Bytes/ cycle
# Peak Combined bandwidth: 28 Bytes/ cycle
# X Reuse Distance (cycles): 2
# Y Reuse Distance (cycles): 0
# Z Reuse Distance (cycles): 4

# %% [markdown]
# Finally we print the actual results of the computation

# %%
print("Matrix X:")
for row in X:
    print(row)

print("\nMatrix Y:")
for row in Y:
    print(row)

print("\nResult Z:")
for row in Z:
    print(row)
# Out:
# Matrix X:
# ['00000000', '10111000', '00010101', '00011011']
# ['00111011', '11101001', '11101011', '01110011']
# ['00100010', '11111000', '00111110', '01011111']
# ['11111110', '00111000', '00010110', '00111000']
#
# Matrix Y:
# ['01000111', '10110001', '11000101', '01101110']
# ['11100011', '00110110', '11111101', '01100110']
# ['01010100', '11010001', '10001000', '00111110']
# ['11101101', '11000110', '11110001', '00000000']
#
# Result Z:
# ['000000001100001100001011', '000000000100110011010111', '000000001101101001101011', '000000000100111001100110']
# ['000000011001011010001011', '000000010111001010111110', '000000011111110011000111', '000000001010111100011010']
# ['000000010101000110100001', '000000001100011111101010', '000000011000100110100001', '000000001000000001110000']
# ['000000001011001100101010', '000000001111100010110100', '000000010011101100110110', '000000001000100011001000']
